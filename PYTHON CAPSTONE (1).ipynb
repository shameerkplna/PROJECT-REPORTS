# %% [markdown]
# <a href="https://colab.research.google.com/github/shameerkplna/FINACIAL-REPORT/blob/main/PYTHON%20CAPSTONE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv(r'/content/myexcel - myexcel.csv.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Replace the existing 'height' column with the new random heights
random_heights = np.random.randint(150, 181, size=len(df))
df['height'] = random_heights
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary  height
# 0                Texas  7730337.0     180
# ...

# %%
#Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

team_counts = df['Team'].value_counts()
team_percentages = (team_counts / len(df)) * 100
team_distribution = pd.DataFrame({'Team': team_counts.index, 'Count': team_counts.values, 'Percentage': team_percentages.values})
print(team_distribution)

#Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Team', y='Percentage', data=team_distribution)
plt.xlabel('Team')
plt.ylabel('Percentage of Employees')
plt.title('Distribution of Employees Across Teams')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#                       Team  Count  Percentage
# 0     New Orleans Pelicans     19    4.148472
# 1        Memphis Grizzlies     18    3.930131
# 2                Utah Jazz     16    3.493450
# 3          New York Knicks     16    3.493450
# 4          Milwaukee Bucks     16    3.493450
# 5            Brooklyn Nets     15    3.275109
# 6   Portland Trail Blazers     15    3.275109
# 7    Oklahoma City Thunder     15    3.275109
# 8           Denver Nuggets     15    3.275109
# 9       Washington Wizards     15    3.275109
# 10              Miami Heat     15    3.275109
# 11       Charlotte Hornets     15    3.275109
# 12           Atlanta Hawks     15    3.275109
# 13       San Antonio Spurs     15    3.275109
# 14         Houston Rockets     15    3.275109
# 15          Boston Celtics     15    3.275109
# 16          Indiana Pacers     15    3.275109
# 17         Detroit Pistons     15    3.275109
# 18     Cleveland Cavaliers     15    3.275109
# ...

# %%
# Segregate employees based on their positions
position_counts = df['Position'].value_counts()
position_percentages = (position_counts / len(df)) * 100
position_distribution = pd.DataFrame({
    'Position': position_counts.index,
    'Count': position_counts.values,
    'Percentage': position_percentages.values
})
print(position_distribution)

# Bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Position', y='Percentage', data=position_distribution)
plt.xlabel('Position')
plt.ylabel('Percentage of Employees')
plt.title('Distribution of Employees Across Positions')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#   Position  Count  Percentage
# 0       SG    102   22.270742
# 1       PF    100   21.834061
# 2       PG     92   20.087336
# 3       SF     85   18.558952
# 4        C     79   17.248908

# %%
#Identify the predominant age group among employees.

if 'Age' in df.columns:
    #Using value_counts()
    age_counts = df['Age'].value_counts()
    predominant_age = age_counts.index[0]
    print(f"The predominant age is: {predominant_age}")

    #Using a histogram
    plt.figure(figsize=(10, 6))
    sns.histplot(df['Age'], kde=True)
    plt.xlabel('Age')
    plt.ylabel('Number of Employees')
    plt.title('Distribution of Employee Ages')
    plt.show()

    #Using age bins
    bins = [0, 20, 30, 40, 50, 60, float('inf')]
    labels = ['<20', '20-29', '30-39', '40-49', '50-59', '60+']
    df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

    age_group_counts = df['Age Group'].value_counts()
    predominant_age_group = age_group_counts.index[0]
    print(f"The predominant age group is: {predominant_age_group}")

    plt.figure(figsize=(10, 6))
    sns.countplot(x='Age Group', data=df)
    plt.xlabel('Age Group')
    plt.ylabel('Number of Employees')
    plt.title('Distribution of Employees by Age Group')
    plt.show()
else:
    print("The 'Age' column is not found in the dataframe.")
# Out:
# The predominant age is: 24
# The predominant age group is: 20-29

# %%
#Discover which team and position have the highest salary expenditure.

salary_expenditure = df.groupby(['Team', 'Position'])['Salary'].sum().reset_index()

max_expenditure_row = salary_expenditure.loc[salary_expenditure['Salary'].idxmax()]

print(f"The team and position with the highest salary expenditure are: {max_expenditure_row['Team']} - {max_expenditure_row['Position']}")
print(f"Total Salary Expenditure: {max_expenditure_row['Salary']}")
# Out:
# The team and position with the highest salary expenditure are: Los Angeles Lakers - SF
# Total Salary Expenditure: 31866445.0

# %%
#Investigate if there's any correlation between age and salary, and represent it visually.

if 'Age' in df.columns and 'Salary' in df.columns:

    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='Age', y='Salary', data=df)
    plt.xlabel('Age')
    plt.ylabel('Salary')
    plt.title('Correlation between Age and Salary')
    plt.show()

    correlation = df['Age'].corr(df['Salary'])
    print(f"Correlation coefficient between Age and Salary: {correlation}")

else:
    print("Either 'Age' or 'Salary' column is missing in the DataFrame.")
# Out:
# Correlation coefficient between Age and Salary: 0.21400941226570971

# %%
#Analyze the distribution of employees across different teams.
plt.figure(figsize=(10, 6))
df['Team'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Employees Across Teams')
plt.ylabel('')
plt.show()

#Analyze the distribution of employees across different positions.
plt.figure(figsize=(12, 6))
sns.countplot(x='Position', data=df)
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.title('Distribution of Employees Across Positions')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()


#Visualize the distribution of employee ages.
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=10, kde=True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Employee Ages')
plt.show()


#Identify the team and position with the highest salary expenditure.
salary_expenditure = df.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x='Team', y='Salary', hue='Position', data=salary_expenditure)
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.title('Salary Expenditure by Team and Position')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

#Investigate the correlation between age and salary.
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Salary', data=df)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation between Age and Salary')
plt.show()

# %%
# Data Story:

# Team Distribution:
# The analysis reveals the distribution of employees across different teams.
# The bar chart and pie chart clearly show the percentage of employees in each team, offering a quick overview of team sizes.

# Position Distribution:
# Similar to team distribution, the analysis of employee positions provides insight into the workforce composition.
# The bar chart visually represents the percentage of employees holding each position within the company.

# Predominant Age Group:
# The analysis identified the most frequent age group within the company.
# The predominant age is 24 and age group is 20-29
# The histogram and countplot effectively visualize the age distribution, allowing for identification of the dominant age cohort.

# Salary Expenditure:
# The analysis identified the team and position with the highest salary expenditure.
# The team and position with the highest salary expenditure are: Los Angeles Lakers - SF
# Total Salary Expenditure are : 31866445.0
# The bar plot breaks this down by both team and position, giving a more granular view of spending.
# Comparing salary expenditure against performance metrics would help quantify the return on investment in salaries.

# Age-Salary Correlation:
# The scatter plot and correlation coefficient reveal the relationship between employee age and salary.
# Correlation coefficient between Age and Salary: 0.21400941226570971
